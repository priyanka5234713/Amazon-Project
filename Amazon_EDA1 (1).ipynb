# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Plot settings
plt.figure(figsize=(10,6))
sns.set(style="whitegrid")

# %%
# Load dataset
titles_df= pd.read_csv('/Users/priyanka/Downloads/titles.csv')
credits_df= pd.read_csv('/Users/priyanka/Downloads/credits.csv')

# %%
# View Row
df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %%
# Shape of dataset
df.shape   # (rows, columns)
# Out:
# (9871, 15)

# %%
# Dataset info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %%
# Statistical summary (numeric columns)
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   9871.000000  9871.000000  1357.000000  8850.000000  8.840000e+03
# mean    2001.327221    85.973052     2.791452     5.976395  8.533614e+03
# std       25.810071    33.512466     4.148958     1.343842  4.592015e+04
# min     1912.000000     1.000000     1.000000     1.100000  5.000000e+00
# 25%     1995.500000    65.000000     1.000000     5.100000  1.170000e+02
# 50%     2014.000000    89.000000     1.000000     6.100000  4.625000e+02
# 75%     2018.000000   102.000000     3.000000     6.900000  2.236250e+03
# max     2022.000000   549.000000    51.000000     9.900000  1.133692e+06
#
#        tmdb_popularity   tmdb_score
# count      9324.000000  7789.000000
# mean          6.910204     5.984247
# std          30.004098     1.517986
# min           0.000011     0.800000
# 25%           1.232000     5.100000
# 50%           2.536000     6.000000
# 75%           5.634000     6.900000
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
# Check missing values
df.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Standardize text columns
df['type'] = df['type'].str.strip().str.title()
df['title'] = df['title'].str.strip()

# %%
# Remove duplicates
df.drop_duplicates(inplace=True)

# %%
# Count content types
content_count = df['type'].value_counts()

# Display counts
content_count
# Out:
# type
# Movie    8511
# Show     1357
# Name: count, dtype: int64

# %%
#Count of Movies vs TV Shows

# %%
Count of Movies vs TV Shows  of content type distribution.
import matplotlib.pyplot as plt

# Plot bar chart
content_count.plot(kind='bar')

# Chart formatting
plt.title("Count of Movies vs TV Shows")
plt.xlabel("Content Type")
plt.ylabel("Number of Titles")
plt.xticks(rotation=0)

# Show plot
plt.show()

# %%
# Count number of titles released each year
release_year_count = df['release_year'].value_counts().sort_index()

# Display result
release_year_count
# Out:
# release_year
# 1912      1
# 1914      2
# 1915      5
# 1916      2
# 1917      1
#        ...
# 2018    685
# 2019    807
# 2020    698
# 2021    856
# 2022     89
# Name: count, Length: 110, dtype: int64

# %%
# Distribution of content across release years showing number of releases over time.
import matplotlib.pyplot as plt

release_year_count.plot(kind='line', marker='o')

plt.title("Number of Releases Over Time")
plt.xlabel("Release Year")
plt.ylabel("Number of Titles")
plt.grid(True)
plt.show()

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
genres = df['genres'].str.split(', ')
genres_exploded = genres.explode()

top_10_genres = genres_exploded.value_counts().head(10)
top_10_genres
# Out:
# genres
# ['drama'       1718
# 'drama']       1145
# 'drama'         991
# ['comedy'       922
# ['thriller'     912
# ['drama']       908
# 'romance']      774
# 'action'        714
# 'comedy'        713
# ['comedy']      686
# Name: count, dtype: int64

# %%
#top 10 genres.
import matplotlib.pyplot as plt

top_10_genres.plot(kind='bar')
plt.title("Top 10 Most Common Genres")
plt.xlabel("Genres")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.show()

# %%
#Content Type by Rating
df['rating'] = 'Not Rated'

# %%
for col in df.columns:
    if 'rat' in col.lower() or 'cert' in col.lower():
        print(col)
# Out:
# age_certification
# rating

# %%
df['rating'] = np.where(
    df['type'] == 'Movie',
    'Movie Rating Not Available',
    'TV Rating Not Available'
)

# %%
rating_type_ct = pd.crosstab(df['rating'], df['type'])

rating_type_ct.plot(kind='bar')

plt.title("Content Type by Rating (Movies vs TV Shows)")
plt.xlabel("Rating")
plt.ylabel("Number of Titles")
plt.xticks(rotation=45)
plt.legend(title="Content Type")
plt.show()

# %%
#content ratin g distrubution

# %%
rating_count = df['rating'].value_counts()
rating_count
# Out:
# rating
# Movie Rating Not Available    8511
# TV Rating Not Available       1357
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

rating_count.plot(kind='barh')

plt.title("Content Rating Distribution (Including Not Rated)")
plt.xlabel("Number of Titles")
plt.ylabel("Rating")
plt.gca().invert_yaxis()
plt.show()

# %%
# Fill missing genres
df['genres'] = df['genres'].fillna('Unknown')

# Create exploded genre dataframe
genre_exploded = df[['type', 'genres']].copy()

# Split multiple genres
genre_exploded['genre'] = genre_exploded['genres'].str.split(', ')

# Explode into rows
genre_exploded = genre_exploded.explode('genres')

# Check result
genre_exploded.head()
# Out:
#     type                                             genres  \
# 0   Show  ['comedy', 'family', 'animation', 'action', 'f...
# 1  Movie  ['action', 'drama', 'war', 'western', 'comedy'...
# 2  Movie                        ['romance', 'war', 'drama']
# 3  Movie                     ['comedy', 'drama', 'romance']
# 4  Movie                   ['thriller', 'drama', 'romance']
#
#                                                genre
# 0  [['comedy', 'family', 'animation', 'action', '...
# 1  [['action', 'drama', 'war', 'western', 'comedy...
# 2                      [['romance', 'war', 'drama']]
# 3                   [['comedy', 'drama', 'romance']]
# 4                 [['thriller', 'drama', 'romance']]

# %%
# Drop rows where genre is still a list (edge case)
genre_exploded = genre_exploded[
    ~genre_exploded['genre'].apply(lambda x: isinstance(x, list))
]

# %%
genre_type_table = pd.crosstab(
    genre_exploded['genre'],
    genre_exploded['type']
)

genre_type_table.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Convert crosstab values to numeric
genre_type_table = genre_type_table.apply(pd.to_numeric, errors='coerce').fillna(0)

# %%
top_genres = genre_exploded['genre'].value_counts().head(10).index

# %%
print(genre_exploded.columns)
print(genre_type_table.dtypes)
# Out:
# Index(['type', 'genres', 'genre'], dtype='object')
# Series([], dtype: object)

# %%
genre_type_table = genre_type_table.apply(pd.to_numeric, errors='coerce')
genre_type_table = genre_type_table.fillna(0)

# %%
genre_type_table = (
    genre_type_table
    .apply(pd.to_numeric, errors='coerce')
    .fillna(0)
)

# %%
genre_type_table = genre_type_table.astype(int)

# %%
genre_type_table.dtypes
# Out:
# Series([], dtype: object)

# %%
# Make sure genre and type are strings
genre_exploded['genre'] = genre_exploded['genre'].astype(str)
genre_exploded['type'] = genre_exploded['type'].astype(str)

# Recreate crosstab
genre_type_table = pd.crosstab(
    genre_exploded['genre'],
    genre_exploded['type']
)

# %%
for col in genre_type_table.columns:
    genre_type_table[col] = pd.to_numeric(
        genre_type_table[col],
        errors='coerce'
    )

# %%
genre_type_table = genre_type_table.fillna(0).astype(int)

# %%
print(genre_type_table.dtypes)
# Out:
# Series([], dtype: object)

# %%
df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
titles_df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
credits_df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
# content type by id

# %%
merged_df = pd.merge(
    titles_df,
    credits_df,
    on='id',
    how='left'
)

# %%
merged_df['type'].value_counts().plot(kind='bar')
plt.title("Movies vs TV Shows (Merged Data)")
plt.xlabel("Content Type")
plt.ylabel("Count")
plt.show()

# %%
# Top 10 Countries

# %%
titles_df['production_countries'].value_counts().head(10)
# Out:
# production_countries
# ['US']    4810
# ['IN']    1048
# []         821
# ['GB']     667
# ['CA']     321
# ['JP']     172
# ['AU']     143
# ['XX']     120
# ['CN']     105
# ['FR']      93
# Name: count, dtype: int64

# %%
titles_df['production_countries'].value_counts().head(10).plot(kind='bar')
plt.title("Top 10 Content Producing Countries")
plt.show()
